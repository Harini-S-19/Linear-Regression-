# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("canada_per_capita_income.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  year  per capita income (US$)
# 0         1.0  1970              3399.299037
# 1         2.0  1971              3768.297935
# 2         3.0  1972              4251.175484
# 3         4.0  1973              4804.463248
# 4         5.0  1974              5576.514583

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['year']], df[['per capita income (US$)']])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year, df['per capita income (US$)'], color='red', marker='+')
plt.plot(df.year, reg.predict(df[['year']]), color='blue')

# %%
p=reg.predict(df[['year']])

# %%
df['year']=p

# %%
df.to_csv("canada_per_capita_income.csv",index=False)

# %%
df.head()
# Out:
#    index  year  per capita income (US$)
# 0    1.0  1970              3399.299037
# 1    2.0  1971              3768.297935
# 2    3.0  1972              4251.175484
# 3    4.0  1973              4804.463248
# 4    5.0  1974              5576.514583

# %%
# Drop it from your current DataFrame memory
df = df.drop(columns=['index'])

# Check your data again
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
